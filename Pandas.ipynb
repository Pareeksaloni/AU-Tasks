# %%
import pandas as pd

# %%
s1=pd.Series([100,200,300,400])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
s2=pd.Series([100,200,300,400],index=["a","b","c","d"])

# %%
print(s2)
# Out:
# a    100
# b    200
# c    300
# d    400
# dtype: int64

# %%
s2.iloc[2] ##Used to extract from index value
# Out:
# np.int64(300)

# %%
s=["Saloni","shrey","sohail","diksha"]
m=[1000,900,800,700]

# %%
se=pd.Series(m,index=s)

# %%
se
# Out:
# Saloni    1000
# shrey      900
# sohail     800
# diksha     700
# dtype: int64

# %%
se.loc["Saloni"] ## Used to extract from elememts
# Out:
# np.int64(1000)

# %%
d="2025/05/24"
d1=pd.to_datetime(d)

# %%
date = pd.to_datetime("5/1/2023")

# %%
date.day
# Out:
# 1

# %%
date.day_name()
# Out:
# 'Monday'

# %%
dict1={"name":["a","b","c","d"],"marks":[1,2,3,4],"Grade":["A","B","C","D"]}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#   name  marks Grade
# 0    a      1     A
# 1    b      2     B
# 2    c      3     C
# 3    d      4     D

# %%
df.iloc[0:2]
# Out:
#   name  marks Grade
# 0    a      1     A
# 1    b      2     B

# %%
df.loc[2:3]
# Out:
#   name  marks Grade
# 2    c      3     C
# 3    d      4     D

# %%
import numpy as np

# %% [markdown]
# **ENCODING TYPES:**
#
# 1. utf-8
# 2. utf-16
# 3. latin1 -(ISO-8859-1)
# 4. Windows-1252

# %%
df=pd.read_csv("laptops.xls",encoding = "latin1")

# %%
df
# Out:
#      Manufacturer                           Model Name            Category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size                                      Screen  \
# ...

# %%
df.head() ##Default top 5
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %% [markdown]
# **If head was not the option** then we can make a function

# %%
def head1(dataframe,n):
  return df.iloc[0:n]

# %%
head1(df,7)
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
# 5         Acer     Aspire 3   Notebook       15.6"
# 6        Apple  MacBook Pro  Ultrabook       15.4"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
# 5                            1366x768     AMD A9-Series 9420 3GHz   4GB
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   object
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   object
#  12  Price (Euros)             1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %%
df['Manufacturer']
# Out:
# 0        Apple
# 1        Apple
# 2           HP
# 3        Apple
# 4        Apple
#          ...
# 1298    Lenovo
# 1299    Lenovo
# 1300    Lenovo
# 1301        HP
# 1302      Asus
# Name: Manufacturer, Length: 1303, dtype: object

# %%
len(df['Manufacturer'])
# Out:
# 1303

# %%
new_manufacturer=[]
for i in df['Manufacturer']:
  x=i.upper()
  new_manufacturer.append(x)

# %%
test=pd.Series(new_manufacturer)

# %%
test[0:3]
# Out:
# 0    APPLE
# 1    APPLE
# 2       HP
# dtype: object

# %%
df['Manufacturer']=test

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        APPLE  MacBook Pro  Ultrabook       13.3"
# 1        APPLE  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        APPLE  MacBook Pro  Ultrabook       15.4"
# 4        APPLE  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df1=pd.read_csv("laptops.xls",encoding = "latin1")

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df1['Manufacturer']=df1['Manufacturer'].apply(lambda x:x.upper())

# %%
df1.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        APPLE  MacBook Pro  Ultrabook       13.3"
# 1        APPLE  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        APPLE  MacBook Pro  Ultrabook       15.4"
# 4        APPLE  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df1['Operating System'].apply(lambda x: "NA" if x=="No OS" else x)
# Out:
# 0         macOS
# 1         macOS
# 2            NA
# 3         macOS
# 4         macOS
#          ...
# 1298    Windows
# 1299    Windows
# 1300    Windows
# 1301    Windows
# 1302    Windows
# Name: Operating System, Length: 1303, dtype: object

# %%
df1.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %% [markdown]
# Convert the space between variables into _ and remove before and after space from the variable and like this.

# %%
def clean_col(col):
  col=col.strip()
  col=col.replace(" ","_")
  col=col.replace(")","")
  col=col.replace("(","")
  return col

# %%
new_col=[]
for i in df.columns:
  x=clean_col(i)
  new_col.append(x)

# %%
new_col
# Out:
# ['Manufacturer',
#  'Model_Name',
#  'Category',
#  'Screen_Size',
#  'Screen',
#  'CPU',
#  'RAM',
#  'Storage',
#  'GPU',
#  'Operating_System',
#  'Operating_System_Version',
#  'Weight',
#  'Price_Euros']

# %%
df.columns=new_col

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model_Name', 'Category', 'Screen_Size', 'Screen',
#        'CPU', 'RAM', 'Storage', 'GPU', 'Operating_System',
#        'Operating_System_Version', 'Weight', 'Price_Euros'],
#       dtype='object')

# %%
df
# Out:
#      Manufacturer                           Model_Name            Category  \
# 0           APPLE                          MacBook Pro           Ultrabook
# 1           APPLE                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           APPLE                          MacBook Pro           Ultrabook
# 4           APPLE                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       LENOVO                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       LENOVO                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       LENOVO                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         ASUS  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen_Size                                      Screen  \
# ...

# %%
df["Screen_Size"].unique()
# Out:
# array(['13.3"', '15.6"', '15.4"', '14.0"', '12.0"', '11.6"', '17.3"',
#        '10.1"', '13.5"', '12.5"', '13.0"', '18.4"', '13.9"', '12.3"',
#        '17.0"', '15.0"', '14.1"', '11.3"'], dtype=object)

# %%
'''df["Screen_Size"].apply(lambda x: x.replace('"',""))'''
                                                #####OR#########
df['Screen_Size']=df['Screen_Size'].str.replace('"','').astype("float")

# %%
df['Screen_Size']
# Out:
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
#         ...
# 1298    14.0
# 1299    13.3
# 1300    14.0
# 1301    15.6
# 1302    15.6
# Name: Screen_Size, Length: 1303, dtype: float64

# %%
def test2(x):
    return x[0].upper()+x[1:].lower()

# %%
df['Manufacturer']=df['Manufacturer'].apply(test2)

# %%
df['Manufacturer']
# Out:
# 0        Apple
# 1        Apple
# 2           Hp
# 3        Apple
# 4        Apple
#          ...
# 1298    Lenovo
# 1299    Lenovo
# 1300    Lenovo
# 1301        Hp
# 1302      Asus
# Name: Manufacturer, Length: 1303, dtype: object

# %%
cpu_company=df["CPU"].str.split().apply(lambda x : x[0])

# %%
cpu_company.value_counts(normalize=True,dropna=False)
# Out:
# CPU
# Intel      0.951650
# AMD        0.047583
# Samsung    0.000767
# Name: proportion, dtype: float64

# %%
type(cpu_company)
# Out:
# pandas.core.series.Series

# %%
df2=pd.DataFrame({"A":[1,2,np.nan,np.nan ]})

# %%
df2.mean()
# Out:
# A    1.5
# dtype: float64

# %%
with pd.ExcelWriter("test.xlsx") as writer:
    df.to_excel(writer)   ###This helps to fill all value into excel and create a new excel file.

# %%
df.head()
# Out:
#   Manufacturer   Model_Name   Category  Screen_Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           Hp       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating_System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df.describe()
# Out:
#        Screen_Size
# count  1303.000000
# mean     15.017191
# std       1.426304
# min      10.100000
# 25%      14.000000
# 50%      15.600000
# 75%      15.600000
# max      18.400000

# %%
df.isnull().sum()
# Out:
# Manufacturer                  0
# Model_Name                    0
# Category                      0
# Screen_Size                   0
# Screen                        0
# CPU                           0
# RAM                           0
# Storage                       0
# GPU                           0
# Operating_System              0
# Operating_System_Version    170
# Weight                        0
# Price_Euros                   0
# dtype: int64

# %%
df['Operating_System_Version']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1298     10
# 1299     10
# 1300     10
# 1301     10
# 1302     10
# Name: Operating_System_Version, Length: 1303, dtype: object

# %% [markdown]
# Missing at Random
#
# Missing completely at random ????

# %%
df['Operating_System_Version'].unique()
# Out:
# array([nan, '10', 'X', '10 S', '7'], dtype=object)

# %%
t=df['Operating_System_Version'].isnull()

# %%
r=df[t]

# %%
r[['Operating_System','Operating_System_Version']]
# Out:
#      Operating_System Operating_System_Version
# 0               macOS                      NaN
# 1               macOS                      NaN
# 2               No OS                      NaN
# 3               macOS                      NaN
# 4               macOS                      NaN
# ...               ...                      ...
# 1267            Linux                      NaN
# 1277            Linux                      NaN
# 1281            Linux                      NaN
# 1291            Linux                      NaN
# 1295            Linux                      NaN
#
# [170 rows x 2 columns]

# %%
s=df.loc[df["Operating_System_Version"].isnull(),"Operating_System"]

# %%
s.value_counts()
# Out:
# Operating_System
# No OS        66
# Linux        62
# Chrome OS    27
# macOS        13
# Android       2
# Name: count, dtype: int64

# %%
mac_os_rows = df[df['Operating_System'] == 'Mac OS']

# %%
mac_os_rows
# Out:
#      Manufacturer   Model_Name   Category  Screen_Size  \
# 6           Apple  MacBook Pro  Ultrabook         15.4
# 26          Apple  MacBook Air  Ultrabook         13.3
# 34          Apple  MacBook Air  Ultrabook         13.3
# 794         Apple  MacBook 12"  Ultrabook         12.0
# 1069        Apple  MacBook 12"  Ultrabook         12.0
# 1193        Apple  MacBook 12"  Ultrabook         12.0
# 1210        Apple  MacBook 12"  Ultrabook         12.0
# 1234        Apple  MacBook Air  Ultrabook         11.6
#
#                                   Screen                   CPU   RAM  \
# 6     IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# 26                              1440x900  Intel Core i5 1.6GHz   8GB
# 34                              1440x900  Intel Core i5 1.6GHz   8GB
# 794   IPS Panel Retina Display 2304x1440   Intel Core M 1.2GHz   8GB
# 1069  IPS Panel Retina Display 2304x1440   Intel Core M 1.1GHz   8GB
# ...

# %%
df['RAM']=df['RAM'].str.replace("GB","").astype("float")

# %%
df["RAM"]
# Out:
# 0        8.0
# 1        8.0
# 2        8.0
# 3       16.0
# 4        8.0
#         ...
# 1298     4.0
# 1299    16.0
# 1300     2.0
# 1301     6.0
# 1302     4.0
# Name: RAM, Length: 1303, dtype: float64

# %%
df['Operating_System'] = df['Operating_System'].replace('macOS','Mac OS')

# %%
df['Operating_System'].unique()
# Out:
# array(['Mac OS', 'No OS', 'Windows', 'Linux', 'Android', 'Chrome OS'],
#       dtype=object)

# %%
df['Operating_System'].value_counts()
# Out:
# Operating_System
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# Mac OS         21
# Android         2
# Name: count, dtype: int64

# %%
v= df['Operating_System']== "Mac OS"

# %%
v
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Operating_System, Length: 1303, dtype: bool

# %%
df.loc[v, 'Operating_System_Version'] = df.loc[v, 'Operating_System_Version'].replace("NaN", "X")

# %%
mac_os_rows = df[df['Operating_System'] == 'Mac OS']

# %%
mac_os_rows
# Out:
#      Manufacturer   Model_Name   Category  Screen_Size  \
# 0           Apple  MacBook Pro  Ultrabook         13.3
# 1           Apple  Macbook Air  Ultrabook         13.3
# 3           Apple  MacBook Pro  Ultrabook         15.4
# 4           Apple  MacBook Pro  Ultrabook         13.3
# 6           Apple  MacBook Pro  Ultrabook         15.4
# 7           Apple  Macbook Air  Ultrabook         13.3
# 12          Apple  MacBook Pro  Ultrabook         15.4
# 14          Apple  MacBook 12"  Ultrabook         12.0
# 15          Apple  MacBook Pro  Ultrabook         13.3
# 17          Apple  MacBook Pro  Ultrabook         15.4
# 26          Apple  MacBook Air  Ultrabook         13.3
# 34          Apple  MacBook Air  Ultrabook         13.3
# 45          Apple  MacBook Pro  Ultrabook         13.3
# 81          Apple  MacBook 12"  Ultrabook         12.0
# 249         Apple  MacBook Pro  Ultrabook         13.3
# 270         Apple  MacBook Pro  Ultrabook         13.3
# ...

# %%
import matplotlib.pyplot as plt

# %%
if 'Screen_Size' in df.columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df['Screen_Size'].dropna(), bins=20) # Drop NaN values for histogram
    plt.xlabel('Screen Size')
    plt.ylabel('Frequency')
    plt.title('Distribution of Screen Sizes')
    plt.grid(True)
    plt.show()

# %%
Price_Euros_count = df['Price_Euros'].value_counts().sum()

# %%
Price_Euros_count
# Out:
# np.int64(1303)

# %%
df.head(3)
# Out:
#   Manufacturer   Model_Name   Category  Screen_Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           Hp       250 G6   Notebook         15.6
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8.0
# 1                            1440x900        Intel Core i5 1.8GHz  8.0
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8.0
#
#                Storage                           GPU Operating_System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640           Mac OS
# 1  128GB Flash Storage        Intel HD Graphics 6000           Mac OS
# 2            256GB SSD         Intel HD Graphics 620            No OS
#
#   Operating_System_Version  Weight Price_Euros
# 0                      NaN  1.37kg     1339,69
# 1                      NaN  1.34kg      898,94
# ...

# %%
df.groupby('Manufacturer')['Screen_Size'].mean().sort_values()
# Out:
# Manufacturer
# Google       12.300000
# Huawei       13.000000
# Apple        13.247619
# Mediacom     13.457143
# Microsoft    13.500000
# Samsung      13.822222
# Vero         13.825000
# Toshiba      14.354167
# Xiaomi       14.450000
# Chuwi        14.500000
# Razer        14.514286
# Lenovo       14.872727
# Hp           14.943066
# Acer         15.063107
# Lg           15.066667
# Dell         15.136027
# Asus         15.450000
# Fujitsu      15.600000
# Msi          16.442593
# Name: Screen_Size, dtype: float64

# %%
df.groupby(['Category','Manufacturer'])['Screen_Size'].mean().sort_values()
# Out:
# Category            Manufacturer
# 2 in 1 Convertible  Mediacom        11.600000
# Netbook             Acer            11.600000
#                     Asus            11.600000
#                     Dell            11.600000
#                     Samsung         11.600000
#                     Lenovo          11.825000
#                     Hp              12.100000
# Ultrabook           Google          12.300000
#                     Razer           12.500000
# 2 in 1 Convertible  Acer            12.750000
# Ultrabook           Huawei          13.000000
# 2 in 1 Convertible  Hp              13.189474
# Ultrabook           Apple           13.247619
#                     Xiaomi          13.300000
#                     Toshiba         13.466667
#                     Microsoft       13.500000
#                     Dell            13.520408
# 2 in 1 Convertible  Lenovo          13.616667
#                     Asus            13.623077
#                     Samsung         13.650000
# ...

# %%
df.groupby(['Category','Manufacturer'])['Screen_Size'].agg(['mean','max','min'])
# Out:
#                                       mean   max   min
# Category           Manufacturer
# 2 in 1 Convertible Acer          12.750000  14.0  11.6
#                    Asus          13.623077  15.6  11.6
#                    Dell          14.173333  17.3  11.6
#                    Hp            13.189474  15.6  11.6
#                    Lenovo        13.616667  15.6  10.1
#                    Mediacom      11.600000  11.6  11.6
#                    Samsung       13.650000  15.0  12.3
# Gaming             Acer          16.237500  17.3  15.6
#                    Asus          16.701852  17.3  15.6
#                    Dell          16.152500  17.3  15.6
#                    Hp            16.875000  17.3  15.6
#                    Lenovo        15.812500  17.3  15.6
#                    Msi           16.442593  18.4  14.0
#                    Razer         15.320000  17.3  14.0
# Netbook            Acer          11.600000  11.6  11.6
# ...

# %%
df.groupby(['Category','Manufacturer'])['Screen_Size'].agg(['mean']).plot(kind='bar')
# Out:
# <Axes: xlabel='Category,Manufacturer'>

# %%
df.groupby(['Category','Manufacturer'])['Screen_Size'].agg(['mean','max','min']).plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby(['Category','Manufacturer'])['Screen_Size'].agg(['mean']).plot(kind='pie',y='mean')
# Out:
# <Axes: ylabel='mean'>

# %%
df.head(3)
# Out:
#   Manufacturer   Model_Name   Category  Screen_Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           Hp       250 G6   Notebook         15.6
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8.0
# 1                            1440x900        Intel Core i5 1.8GHz  8.0
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8.0
#
#                Storage                           GPU Operating_System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640           Mac OS
# 1  128GB Flash Storage        Intel HD Graphics 6000           Mac OS
# 2            256GB SSD         Intel HD Graphics 620            No OS
#
#   Operating_System_Version  Weight Price_Euros
# 0                      NaN  1.37kg     1339,69
# 1                      NaN  1.34kg      898,94
# ...

# %%
df['Screen'].str.contains('Retina')
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Screen, Length: 1303, dtype: bool

# %%
df.loc[df['Screen'].str.contains('Retina')]
# Out:
#      Manufacturer    Model_Name   Category  Screen_Size  \
# 0           Apple   MacBook Pro  Ultrabook         13.3
# 3           Apple   MacBook Pro  Ultrabook         15.4
# 4           Apple   MacBook Pro  Ultrabook         13.3
# 6           Apple   MacBook Pro  Ultrabook         15.4
# 12          Apple   MacBook Pro  Ultrabook         15.4
# 14          Apple   MacBook 12"  Ultrabook         12.0
# 15          Apple   MacBook Pro  Ultrabook         13.3
# 17          Apple   MacBook Pro  Ultrabook         15.4
# 45          Apple   MacBook Pro  Ultrabook         13.3
# 81          Apple   MacBook 12"  Ultrabook         12.0
# 249         Apple   MacBook Pro  Ultrabook         13.3
# 270         Apple   MacBook Pro  Ultrabook         13.3
# 421         Chuwi  LapBook 12.3   Notebook         12.3
# 794         Apple   MacBook 12"  Ultrabook         12.0
# 1069        Apple   MacBook 12"  Ultrabook         12.0
# 1193        Apple   MacBook 12"  Ultrabook         12.0
# ...

# %%
df['Screen_Size'].between(13.3,15.6)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1298    True
# 1299    True
# 1300    True
# 1301    True
# 1302    True
# Name: Screen_Size, Length: 1303, dtype: bool

# %%
df.isna().sum()
# Out:
# Manufacturer                  0
# Model_Name                    0
# Category                      0
# Screen_Size                   0
# Screen                        0
# CPU                           0
# RAM                           0
# Storage                       0
# GPU                           0
# Operating_System              0
# Operating_System_Version    170
# Weight                        0
# Price_Euros                   0
# dtype: int64
